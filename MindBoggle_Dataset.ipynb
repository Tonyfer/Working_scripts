# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
def get_v_a(s):
    if s in name_v_ant:
        return(volum_ant[volum_ant.columns[2]][name_v_ant.index(s)])
    else:
        return ''

def get_v_fs(s):
    if s in name_v_fs:
        return(volum_fs[volum_fs.columns[2]][name_v_fs.index(s)])
    else:
        return ''

# %%
import sys
name_v_ant_template=[]
with open('/data3/cdb/ytong/merged_tables/templates/v_ant.txt','r') as f:
    for line in f:
        name_v_ant_template+=(line.strip('\n').split(','))

        
name_v_fs_template=[]

with open('/data3/cdb/ytong/merged_tables/templates/v_fs.txt','r') as f:
	for line in f:
		name_v_fs_template+=(line.strip('\n').split(','))

# %%
def get_df(cwd, group):
    def get_v_a(s):
        if s in name_v_ant:
            return(volum_ant[volum_ant.columns[2]][name_v_ant.index(s)])
        else:
            return ''

    def get_v_fs(s):
        if s in name_v_fs:
            return(volum_fs[volum_fs.columns[2]][name_v_fs.index(s)])
        else:
            return ''
        
        
    files = os.listdir(cwd)
    fi_list = []
    for name in files:
        if 'sub' in name:
            fi_list.append(name)
    f_list = []
    for path in fi_list:
        a = os.path.exists(cwd+path+'/mindboggle/')
        b = os.path.exists(cwd+path+'/mindboggle/tables/left_cortical_surface/')
        c = os.path.exists(cwd+path+'/mindboggle/tables/right_cortical_surface/')
        #d = os.path.exists(cwd+path+'/mindboggle/tables/thickinthehead_per_ants_cortex_label.csv')
        #e = os.path.exists(cwd+path+'/mindboggle/tables/thickinthehead_per_freesurfer_cortex_label.csv')
        f = os.path.exists(cwd+path+'/mindboggle/tables/volume_per_freesurfer_label.csv')
        g = os.path.exists(cwd+path+'/mindboggle/tables/volume_per_ants_label.csv')
        if a and b and c and f and g:
            f_list.append(path)
    lh = pd.read_csv(cwd+f_list[0]+'/mindboggle/tables/left_cortical_surface/label_shapes.csv')
    name_s_a = ['area' + lh['name'][i] for i in range(len(lh['name']))]
    name_s_tdm = ['tdm' + lh['name'][i] for i in range(len(lh['name']))]
    name_s_t = ['thickness'+lh['name'][i] for i in range(len(lh['name']))]
    #name_t_fs = ['fs_t_'+i for i in name_t_fs_template]
    name_v_fs = ['fs_v_'+i for i in name_v_fs_template]
    #name_t_ant = ['ant_t_'+i for i in name_t_ant_template]
    name_v_ant = ['ant_v_'+i for i in name_v_ant_template]
    var = name_v_fs+name_v_ant+name_s_a+name_s_tdm+name_s_t
    df = pd.DataFrame(np.zeros([1,len(var)]), columns=var)
    i = 0
    for sub in f_list:
        sub = cwd + sub
        #thick_ant = pd.read_csv(sub+'/mindboggle/tables/thickinthehead_per_ants_cortex_label.csv')
        #thick_fs = pd.read_csv(sub+'/mindboggle/tables/thickinthehead_per_freesurfer_cortex_label.csv')
        volum_fs = pd.read_csv(sub+'/mindboggle/tables/volume_per_freesurfer_label.csv')
        volum_ant = pd.read_csv(sub+'/mindboggle/tables/volume_per_ants_label.csv')
        lh = pd.read_csv(sub+'/mindboggle/tables/left_cortical_surface/label_shapes.csv')
        rh = pd.read_csv(sub+'/mindboggle/tables/right_cortical_surface/label_shapes.csv')
        name_v_ant = [volum_ant['name'][i] for i in range(len(volum_ant['name']))]
        value_v_ant = [get_v_a(i) for i in name_v_ant_template]
        #name_v_ant = ['ant_v_'+volum_ant['name'][i] for i in range(len(volum_ant['name']))]
        name_v_fs = [volum_fs['name'][i] for i in range(len(volum_fs['name']))]
        value_v_fs = [get_v_fs(i) for i in name_v_fs_template]
        

        va_l_a = [lh['area'][i] for i in range(len(lh['name']))]
        va_r_a = [rh['area'][i] for i in range(len(rh['name']))]
        #name_s_tdm = ['tdm' + lh['name'][i] for i in range(len(lh['name']))]
        va_l_tdm = [lh['travel depth: median'][i] for i in range(len(lh['name']))]
        va_r_tdm = [rh['travel depth: median'][i] for i in range(len(rh['name']))]
        va_l_th = [lh['freesurfer thickness: median'][i] for i in range(len(lh['name']))]
        va_r_th = [rh['freesurfer thickness: median'][i] for i in range(len(rh['name']))]
        val_a = [va_l_a[i]+va_r_a[i] for i in range(len(va_l_a))]
        val_tdm = [va_l_tdm[i]+va_r_tdm[i] for i in range(len(va_l_tdm))]
        val_th = [va_l_th[i]+va_r_th[i] for i in range(len(va_l_th))]
    
        val = value_v_fs+value_v_ant+val_a+val_tdm+val_th
        df.loc[i] = val
        i+=1
    df['sub'] = f_list
    df['group'] = [group for i in range(len(f_list))]
    return(df)

# %%
get_df('/data2/HBNcore/CMI_HBN_Data/MRI/SI/Release_Derivatives/data_release_ExternalID/',1)
# Out:
#      fs_v_ctx-lh-unknown  fs_v_ctx-lh-bankssts  \
# 0               1039.001              1896.002
# 1                950.000              3443.000
# 2                924.997              2452.993
# 3               1020.998              3574.994
# 4               1061.000              4020.000
# 5                909.000              3491.000
# 6               1092.000              3075.000
# 7                625.996              2875.981
# 8               1003.997              3189.990
# 9               1213.000              3107.000
# 10               719.998              3080.991
# 11               966.005              2785.016
# 12              1437.004              3616.011
# 13              1103.993              3276.979
# 14               648.997              2977.988
# 15              1049.004              1878.007
# 16               964.000              2631.000
# 17               647.000              3504.000
# 18               790.999              2339.997
# ...

# %%
cwd_l = ['/data2/HBNcore/CMI_HBN_Data/MRI/SI/Release_Derivatives/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/RU/Release_Derivatives/R3_20150501_20171131/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/RU/Release_Derivatives/R4_20171201_20180531/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/RU/Release_Derivatives/R5_20180601_20180931/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/RU/Release_Derivatives/R6_20181001_20181231/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/CBIC/Release_Derivatives/R3_20170801_20171131/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/CBIC/Release_Derivatives/R4_20171201_20180531/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/CBIC/Release_Derivatives/R5_20180601_20180931/data_release_ExternalID/',
'/data2/HBNcore/CMI_HBN_Data/MRI/CBIC/Release_Derivatives/R6_20181001_20181231/data_release_ExternalID/']

# %%
df_1 = get_df(cwd_l[0],1)

# %%
df_2 = get_df(cwd_l[1],2)

# %%
df_3 = get_df(cwd_l[2],2)

# %%
df_4 = get_df(cwd_l[3],2)

# %%
df_5 = get_df(cwd_l[4],2)

# %%
def get_df_cbic(cwd, group):
    def get_v_a(s):
        if s in name_v_ant:
            return(volum_ant[volum_ant.columns[2]][name_v_ant.index(s)])
        else:
            return ''

    def get_v_fs(s):
        if s in name_v_fs:
            return(volum_fs[volum_fs.columns[2]][name_v_fs.index(s)])
        else:
            return ''
        
        
    files = os.listdir(cwd)
    fi_list = []
    for name in files:
        if 'sub' in name:
            fi_list.append(name)
    f_list = []
    for path in fi_list:
        a = os.path.exists(cwd+path+'/T1w_VNavNorm/mindboggle/')
        b = os.path.exists(cwd+path+'/T1w_VNavNorm/mindboggle/tables/left_cortical_surface/')
        c = os.path.exists(cwd+path+'/T1w_VNavNorm/mindboggle/tables/right_cortical_surface/')
        #d = os.path.exists(cwd+path+'/mindboggle/tables/thickinthehead_per_ants_cortex_label.csv')
        #e = os.path.exists(cwd+path+'/mindboggle/tables/thickinthehead_per_freesurfer_cortex_label.csv')
        f = os.path.exists(cwd+path+'/T1w_VNavNorm/mindboggle/tables/volume_per_freesurfer_label.csv')
        g = os.path.exists(cwd+path+'/T1w_VNavNorm/mindboggle/tables/volume_per_ants_label.csv')
        if a and b and c and f and g:
            f_list.append(path)
    lh = pd.read_csv(cwd+f_list[0]+'/T1w_VNavNorm/mindboggle/tables/left_cortical_surface/label_shapes.csv')
    name_s_a = ['area' + lh['name'][i] for i in range(len(lh['name']))]
    name_s_tdm = ['tdm' + lh['name'][i] for i in range(len(lh['name']))]
    name_s_t = ['thickness'+lh['name'][i] for i in range(len(lh['name']))]
    #name_t_fs = ['fs_t_'+i for i in name_t_fs_template]
    name_v_fs = ['fs_v_'+i for i in name_v_fs_template]
    #name_t_ant = ['ant_t_'+i for i in name_t_ant_template]
    name_v_ant = ['ant_v_'+i for i in name_v_ant_template]
    var = name_v_fs+name_v_ant+name_s_a+name_s_tdm+name_s_t
    df = pd.DataFrame(np.zeros([1,len(var)]), columns=var)
    i = 0
    for sub in f_list:
        sub = cwd + sub
        #thick_ant = pd.read_csv(sub+'/mindboggle/tables/thickinthehead_per_ants_cortex_label.csv')
        #thick_fs = pd.read_csv(sub+'/mindboggle/tables/thickinthehead_per_freesurfer_cortex_label.csv')
        volum_fs = pd.read_csv(sub+'/T1w_VNavNorm/mindboggle/tables/volume_per_freesurfer_label.csv')
        volum_ant = pd.read_csv(sub+'/T1w_VNavNorm/mindboggle/tables/volume_per_ants_label.csv')
        lh = pd.read_csv(sub+'/T1w_VNavNorm/mindboggle/tables/left_cortical_surface/label_shapes.csv')
        rh = pd.read_csv(sub+'/T1w_VNavNorm/mindboggle/tables/right_cortical_surface/label_shapes.csv')
        name_v_ant = [volum_ant['name'][i] for i in range(len(volum_ant['name']))]
        value_v_ant = [get_v_a(i) for i in name_v_ant_template]
        #name_v_ant = ['ant_v_'+volum_ant['name'][i] for i in range(len(volum_ant['name']))]
        name_v_fs = [volum_fs['name'][i] for i in range(len(volum_fs['name']))]
        value_v_fs = [get_v_fs(i) for i in name_v_fs_template]
        

        va_l_a = [lh['area'][i] for i in range(len(lh['name']))]
        va_r_a = [rh['area'][i] for i in range(len(rh['name']))]
        #name_s_tdm = ['tdm' + lh['name'][i] for i in range(len(lh['name']))]
        va_l_tdm = [lh['travel depth: median'][i] for i in range(len(lh['name']))]
        va_r_tdm = [rh['travel depth: median'][i] for i in range(len(rh['name']))]
        va_l_th = [lh['freesurfer thickness: median'][i] for i in range(len(lh['name']))]
        va_r_th = [rh['freesurfer thickness: median'][i] for i in range(len(rh['name']))]
        val_a = [va_l_a[i]+va_r_a[i] for i in range(len(va_l_a))]
        val_tdm = [va_l_tdm[i]+va_r_tdm[i] for i in range(len(va_l_tdm))]
        val_th = [va_l_th[i]+va_r_th[i] for i in range(len(va_l_th))]
    
        val = value_v_fs+value_v_ant+val_a+val_tdm+val_th
        df.loc[i] = val
        i+=1
    df['sub'] = f_list
    df['group'] = [group for i in range(len(f_list))]
    return(df)

# %%
df_6 = get_df_cbic(cwd_l[5],3)

# %%
df_7 = get_df_cbic(cwd_l[6],3)

# %%
df_8 = get_df_cbic(cwd_l[7],3)

# %%
df_9 = get_df_cbic(cwd_l[8],3)

# %%
df_all = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9], axis=0)

# %%
df_all.to_csv('df_all.csv')

# %%
df_all
# Out:
#     fs_v_ctx-lh-unknown  fs_v_ctx-lh-bankssts  \
# 0              1039.001              1896.002
# 1               950.000              3443.000
# 2               924.997              2452.993
# 3              1020.998              3574.994
# 4              1061.000              4020.000
# 5               909.000              3491.000
# 6              1092.000              3075.000
# 7               625.996              2875.981
# 8              1003.997              3189.990
# 9              1213.000              3107.000
# 10              719.998              3080.991
# 11              966.005              2785.016
# 12             1437.004              3616.011
# 13             1103.993              3276.979
# 14              648.997              2977.988
# 15             1049.004              1878.007
# 16              964.000              2631.000
# 17              647.000              3504.000
# 18              790.999              2339.997
# ...
